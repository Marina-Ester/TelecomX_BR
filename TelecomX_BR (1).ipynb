# %% [markdown]
# #📌 Extracão

# %%
# Telecom X - Análise de Churn de Clientes
# Notebook pronto para GitHub


# --- 1. Importações ---
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# --- 1. Criar dados de teste ---
df = pd.DataFrame({
    'Genero': np.random.choice(['Masculino','Feminino'], 50),
    'Tipo_Contrato': np.random.choice(['Mensal','Anual'], 50),
    'Metodo_Pagamento': np.random.choice(['Boleto','Cartão'], 50),
    'Faturamento_Mensal': np.random.uniform(50,150,50),
    'Meses_Contrato': np.random.randint(1,60,50),
    'Evasao': np.random.choice([0,1], 50)
})

print("✅ Dados de teste criados:")
print(df.head())

# %%
# --- 2. Exploração rápida ---
print("\nInformações gerais do DataFrame:")
print(df.info())
print("\nEstatísticas descritivas:")
print(df.describe())
# Out:
# Informações gerais do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Genero              100 non-null    object
#  1   Tipo_Contrato       100 non-null    object
#  2   Metodo_Pagamento    100 non-null    object
#  3   InternetService     100 non-null    object
#  4   Dependents          100 non-null    int32
#  5   Faturamento_Mensal  100 non-null    float64
#  6   Faturamento_Total   100 non-null    float64
#  7   Meses_Contrato      100 non-null    int32
#  8   Contas_Diarias      100 non-null    float64
#  9   Evasao              100 non-null    int32
# dtypes: float64(3), int32(3), object(4)
# memory usage: 7.4+ KB
# None
#
# Estatísticas descritivas:
#        Dependents  Faturamento_Mensal  Faturamento_Total  Meses_Contrato  \
# count  100.000000          100.000000         100.000000      100.000000
# ...

# %% [markdown]
# #🔧 Transformação

# %%
# --- 3. Gráfico de churn geral ---
df['Evasao'].value_counts().plot(kind='bar', color=['green','red'])
plt.title('Distribuição de Clientes - Churn')
plt.xlabel('Evasão (0=Ficou, 1=Saiu)')
plt.ylabel('Número de Clientes')
plt.show()

# %%
# --- 6. Churn por método de pagamento ---
sns.countplot(x='Metodo_Pagamento', hue='Evasao', data=df, palette=['green','red'])
plt.title('Churn por Método de Pagamento')
plt.show()

# %%
# --- 7. Boxplot de faturamento e meses de contrato ---
sns.boxplot(x='Evasao', y='Faturamento_Mensal', data=df, palette=['green','red'])
plt.title('Faturamento Mensal por Evasão')
plt.show()

# %% [markdown]
# #📊 Carga e análise

# %%
# --- 7. Boxplot de faturamento e meses de contrato ---
sns.boxplot(x='Evasao', y='Faturamento_Mensal', data=df, palette=['green','red'])
plt.title('Faturamento Mensal por Evasão')
plt.show()

# %% [markdown]
# #📄Relatorio Final

# %%
sns.boxplot(x='Evasao', y='Meses_Contrato', data=df, palette=['green','red'])
plt.title('Meses de Contrato por Evasão')
plt.show()
